# %%
a = 10
a = "0"
print(a)
a
# Out:
# 0
# '0'

# %%
A = 1.2
A
# Out:
# 1.2

# %%
txt = "hello world"
txt

'''txt . algo, chama funções pra variavel. talvez equivala a  algo(var);'''
''' para poo, o split seria um metodo do... objeto que a string é'''

spl = txt.split(" ")
print(spl)
# Out:
# ['hello', 'world']

# %%
type (3+4j)
# Out:
# complex

# %%
cpx = 3+4j

type(cpx)

print(cpx)
print(type(cpx))    ''' print (precisa de algo) /// print(type(tipo de que?'''
print(cpx.real)
print(cpx.imag)
'''print(cpx.conjugate)'''

conjug = cpx.conjugate()

print(conjug)
# Out:
# 3.0
# 4.0
# <built-in method conjugate of complex object at 0x7f0303ba4d70>
# (3-4j)

# %%
s = 'hello'
tam = len(s)
s[-1]
print(
s[0],
s[1],
s[2],
s[3],
s[4],

s[-1],
s[-2],
s[-3],
s[-4],
s[-5],

type(s), '''  QNDO APARECER CLASS, SIGNIFICA QUE... É UM OBJ'''
tam
)
# Out:
# h e l l o o l l e h <class 'str'> 5

# %%
s1 = "world"
s1
# Out:
# 'world'

# %%
s2 = 'ola'

# %%
print(s2)
# Out:
# ola

# %%
'''5 - SLICE'''
name = "vinicius"
slc = name[0:3]
slc

'''ou'''

print(name[0:4])
''' por causa disso, so vai imprimiro o print '''

'''6 - SELECT '''
print(name[::2])
''' aqui é pra selecionar. pula de 2 em 2 (ou seja, pulando um caractere) vai o caractere 0, 2, 4...'''
# Out:
# vini
# vncu

# %%
''' 7 -  mais metodos!!!'''

'''esse replace parece ser muito bom!!!'''

print(
name,
name.find('i'),

name[4::]
)

print (name[name.])
# Out:
# vinicius 1 3 cius

# %% [markdown]
# '''onde começa o trecho'''
# name.find('ici'),

# %%
name.replace("i", "e")
# Out:
# 'veneceus'

# %%
caminho = r"C:\Users\vjfr\Desktop\pastinha\teste.txt"
print(caminho)
caminho.replace('\r', '/')
print(caminho)
var = caminho.split('/')
print(var)
# Out:
# C:\Users\vjfr\Desktop\pastinha\teste.txt
# C:\Users\vjfr\Desktop\pastinha\teste.txt
# ['C:\\Users\\vjfr\\Desktop\\pastinha\\teste.txt']

# %%
''' 8 - Lista'''
'''basicamente uma struct'''
'''uma struct é uma lista encadeada?'''
l = ["b", 7.1, 3+4j]

print(

    l[0],
    l[1],
    l[2],
    type(l[2])


)
# Out:
# b 7.1 (3+4j) <class 'complex'>

# %%
''' 9 - print'''
idade = 23+1
print(f"sou {name} e tenho {idade} anos.")
'''mais conhecido como f string. existem infinitas possibilidades de escrita.'''
print(f"sou %s \n e tenho %d anos."%(name, idade))
# Out:
# sou vinicius e tenho 24 anos.
# sou vinicius e tenho 24 anos.

# %%
teste = "s,pa,m"
teste.find('pa')
print(teste[2:4])
'''aqui rola meio que um split. do intevalo. é uma casa até a anterior a ultima declarada. 2:4 vai da 2 até a 4-1'''

print(teste)
cortado = teste.split(",")
'''retorna a var string para uma lista'''
print(cortado)
print (cortado[1])
# Out:
# pa
# s,pa,m
# ['s', 'pa', 'm']
# pa

# %% [markdown]
# 1 - vai ser um pegando e outra dando split e printando o item 2 da lista

# %%
t2 = "Um elefante incomoda muita gente"
t2.find("elefante incomoda")
# Out:
# 3

# %% [markdown]
# 2 - vou tentar...

# %%
receber = ""

# %% [markdown]
# 3 - poxa, fazendo toda em replace?
#
#
# ### EQUIVALE A H3? XML? MD TEM EM... OBSIDIAN, GIT E JUPYTHER?

# %% [markdown]
# AQUI É EM MARKDOWN
#
#
# ### CERQUILHA
# ## SHARP
# - EXEMPLO
# TEM COMO FAZER UMA ABINHA

# %%
frase = "Um elefante incomoda muita gente"
quero = "elefante incomoda"
print(len(quero))
print( frase [ frase.find(quero) : len(quero) + frase.find(quero) ] )
'''print frase [ inicio ate tamanho + inicio(pra n perder)]'''

inicio = frase.find(quero)
tam = len(quero)
print (frase[ inicio : tam + inicio])
# Out:
# 17
# elefante incomoda
# elefante incomoda

# %% [markdown]
# ### 9 - Outra forma de fazer o... exerc 2, que está no keep https://keep.google.com/u/1/#NOTE/11WCQ7cAJ34RQikBP0h7O31Chym9HiO-K99eqXWXYAIHMRtnsJzHxNmw2vPlhsp0

# %%
t = 10
input(t)
print(t)
# Out:
# 1023
# 10

# %% [markdown]
# que doideira, esse input

# %%
string_k = input()
numero_n = int(input())
''' fazer um cast do tipo int'''
somma = string_k + numero_n

print(soma)
# Out:
# 12
# 33
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-01179dd8e5c2> in <cell line: 4>()
#       2 numero_n = int(input())
#       3
# ----> 4 somma = string_k + numero_n
#       5
#       6 print(soma)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# detalhe, so concastena string com string, soma float, com int ou sla... https://www.google.com/search?q=TypeError%3A%20can%20only%20concatenate%20str%20(not%20%22int%22)%20to%20str+site:stackoverflow.com
#
# magina qndo tiver ... com open ia

# %%
palavra = input()
print(palavra.lower]())

'''uppercase e lowercase'''
# Out:
# Ola
# ola

# %% [markdown]
# tip: python foi feito pra simplificar. alguem deve ter criado uma função...

# %% [markdown]
# meio que me perdi em opeações, mas bora lá.

# %%
'''var recebe input_do_user'''
a = float(input("digite 'A' "))
b = float(input("digite 'B' "))
c = float(input("digite 'C' "))
delta = (pow(b,2) - ((4*a)*c))
x1 = ((-b - pow (delta,1/2))/(2*a))
x2 = ((-b + pow (delta,1/2))/(2*a))

print(x1, x2)
# Out:
# digite 'A' 2
# digite 'B' -6
# digite 'C' -8
# -1.0 4.0

# %% [markdown]
# a = 2
# b = -6
# c = -8
#
# 4 e -1

# %%
x = int(input("digite 'X' "))
y = int(input("digite 'Y' "))

z= (pow(x,2)+pow(y,2))/(pow(x-y,2))
z
# Out:
# digite 'X' 4
# digite 'Y' 5
# 41.0

# %%
conj1 = set("Ola")
print(conj1)

# cometário
'''um de área '''

conj1

'''

nome. add
    .union(conj2)
    .remove
    .pop
# Out:
# {'a', 'l', 'O'}

# %% [markdown]
# # 10 -conjuntos
